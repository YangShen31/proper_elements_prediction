# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import math
import matplotlib.patches as patches
from matplotlib.ticker import FormatStrFormatter

from family_utils import slab_d_calc

plt.style.use('../paper.mplstyle')

# %%
plt.style.use('tableau-colorblind10')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

def find_nearest_idx(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

# %% [markdown]
# # Load Model Results and Family Dataset

# %%
df_xgb = pd.read_csv("../data/model_results.csv")
nesvorny_elements = pd.read_csv("../data/nesvorny_catalog_dataset.csv")
df_xgb = pd.merge(df_xgb, nesvorny_elements[["Des'n", 'da', 'de', 'dsini']], on="Des'n", how="inner")
# Out:
# /tmp/ipykernel_472801/3906744179.py:2: DtypeWarning: Columns (0: Des'n) have mixed types. Specify dtype option on import or set low_memory=False.
#   nesvorny_elements = pd.read_csv("../data/nesvorny_catalog_dataset.csv")

# %%
df_xgb["sini"] = np.sin(df_xgb["Incl."]*180/np.pi)
nesvorny_elements["sini"] = np.sin(nesvorny_elements["Incl."]*180/np.pi)
propa = df_xgb["propa"]
prope = df_xgb["prope"]
propsini = df_xgb["propsini"]

test_name_list = df_xgb['Des\'n']

# %%
column_names = ['propa', 'prope', 'propsini', 'g', 's', 'H', 'NumOpps', 'PackedName', 'UnpackedName']
df_Velleda = pd.read_csv("../data/family_tables/inner_126_velleda_fam3.csv", header=None, names=column_names)
def convert_id(val):
	val_str = str(val)
	if val_str.isdigit():
		return int(val_str)
	return val_str

df_Velleda["PackedName"] = df_Velleda["PackedName"].apply(convert_id)
df_Velleda
# Out:
#         propa     prope  propsini          g          s      H  NumOpps  \
# 0    2.438860  0.072280  0.045947  40.851255 -42.703906   9.30       63
# 1    2.441824  0.074053  0.045585  40.951172 -42.878256  17.03       15
# 2    2.435232  0.073062  0.046095  40.759361 -42.565716  17.12       14
# 3    2.438780  0.072035  0.043792  40.879475 -42.708727  17.90       13
# 4    2.440053  0.074322  0.044979  40.913560 -42.815681  17.79       10
# ..        ...       ...       ...        ...        ...    ...      ...
# 303  2.331699  0.076564  0.050382  37.299052 -38.392160  16.93       17
# 304  2.344087  0.075571  0.052807  37.696171 -38.834860  18.74        9
# 305  2.347829  0.073877  0.051834  37.839790 -38.950176  18.38        8
# 306  2.350263  0.074166  0.050439  37.948371 -39.052874  15.93       19
# 307  2.350210  0.072466  0.053420  37.887485 -39.006768  15.69       18
#
#     PackedName UnpackedName
# 0          126          126
# 1        M1071       221071
# 2        T6086       296086
# 3        V6285       316285
# 4        c9945       389945
# ..         ...          ...
# 303      D6551       136551
# 304    K16G46V     2016GV46
# 305    K08D92B     2008DB92
# 306      36971        36971
# 307      42659        42659
#
# [308 rows x 9 columns]

# %%
name_list = df_Velleda["PackedName"]
family_df = nesvorny_elements[nesvorny_elements["Des'n"].isin(name_list)]
family_pred_df = df_xgb[df_xgb["Des'n"].isin(name_list)]
family_df
# Out:
#          Unnamed: 0    Des'n    H_x     G  Epoch          M      Peri.  \
# 125             125      126   9.30  0.15  K239D  255.14519  328.21218
# 1357           1357     1394  11.80  0.15  K239D  304.76605  113.35737
# 3170           3170     3302  12.88  0.15  K239D   24.11047  170.35816
# 3898           3898     4081  12.97  0.15  K239D    9.03054   50.40175
# 5738           5738     6054  14.02  0.15  K239D  332.28805   56.03807
# ...             ...      ...    ...   ...    ...        ...        ...
# 1221936     1221936  K22S33O  18.62  0.15  K239D   87.05225  231.96332
# 1222081     1222081  K22S40V  19.05  0.15  K239D   48.56275   99.78187
# 1227426     1227426  K22SS1D  19.20  0.15  K239D  130.22743  307.76728
# 1236404     1236404  K23M05P  18.24  0.15  K239D  356.50486    6.34339
# 1237350     1237350  K23O23K  18.95  0.15  K239D   56.59293  265.11369
#
#               Node    Incl.         e  ...            da     prope        de  \
# 125       23.24015  2.92339  0.105260  ...  1.200000e-06  0.072280  0.000012
# 1357     178.75383  2.67607  0.076000  ...  6.300000e-08  0.064711  0.000035
# 3170     154.33213  3.38972  0.097005  ...  2.100000e-07  0.069700  0.000027
# 3898     253.67103  1.79789  0.091406  ...  1.100000e-07  0.070390  0.000330
# 5738     261.91143  2.16357  0.102728  ...  7.200000e-07  0.075354  0.000140
# ...            ...      ...       ...  ...           ...       ...       ...
# 1221936  142.90615  3.45654  0.096351  ...  2.500000e-05  0.068497  0.000300
# 1222081  309.53821  2.16197  0.074209  ...  1.100000e-07  0.064095  0.000050
# 1227426   18.39971  3.21980  0.109460  ...  1.500000e-07  0.075389  0.000250
# 1236404  311.93794  1.70404  0.096008  ...  2.100000e-07  0.069915  0.000220
# 1237350  358.68988  2.94706  0.072263  ...  2.200000e-06  0.076988  0.000250
#
#          propsini     dsini          g          s    H_y  NumOpps      sini
# 125      0.045947  0.000038  40.851255 -42.703906   9.30       63 -0.837940
# 1357     0.049413  0.000047  40.734640 -42.502396  11.80       40  0.573296
# 3170     0.054247  0.000032  41.012424 -43.198993  12.88       31 -0.532960
# 3898     0.044817  0.000320  39.018338 -40.138061  12.97       31  0.613945
# 5738     0.052509  0.000230  39.977579 -41.569131  14.02       24 -0.991629
# ...           ...       ...        ...        ...    ...      ...       ...
# 1221936  0.052921  0.000029  40.889495 -42.940522  18.62        1 -0.124493
# 1222081  0.050384  0.000037  40.783990 -42.618238  19.05        1 -0.975645
# 1227426  0.053348  0.000440  38.960132 -40.272668  19.20        1  0.766270
# 1236404  0.041287  0.000410  40.472819 -41.991715  18.24       10 -0.242486
# 1237350  0.050153  0.000360  37.866150 -39.030829  18.95        7 -0.711692
#
# [299 rows x 23 columns]

# %% [markdown]
# # Family Identification Evaluation

# %%
# Calculate the percentage of machine learning prediction still classifies asteroids into the family
family_pred_df = df_xgb[df_xgb["Des'n"].isin(name_list)]

d_df_pred = slab_d_calc(family_df, family_pred_df, df_xgb, "pred")
d_df_osc = slab_d_calc(family_df, family_pred_df, df_xgb, "osculating")

# %%
family_pred_df
# Out:
#         Unnamed: 0  actual_dele  pred_dele  actual_delsini  pred_delsini  \
# 83232   5.600000e-07  0.000150  0.000270 -0.492442
# 97515   6.000000e-08  0.000310  0.000260  0.934196
# 103764  7.100000e-08  0.000046  0.000063 -0.675397
# 112632  9.300000e-07  0.000260  0.000490  0.566125
# 116407  8.400000e-08  0.000150  0.000350  0.912079
# 119391  2.000000e-06  0.000250  0.000280 -0.922523
# 121472  1.700000e-07  0.000260  0.000420 -0.488270
# 128549  2.600000e-07  0.000087  0.000120  0.177477
# 132380  1.900000e-07  0.000096  0.000150  0.467433
# 145122  2.700000e-07  0.000420  0.000760  0.736103
# 146688  1.700000e-07  0.000068  0.000090  0.636128
# 146925  6.000000e-07  0.000120  0.000150  0.010770
# 165750  2.800000e-06  0.000290  0.000280  0.284782
# 167542  2.500000e-07  0.000100  0.000130  0.811225
# 170884  6.300000e-07  0.000270  0.000220 -0.018095
# 174074  3.000000e-07  0.000110  0.000077 -0.944003
# 177288  2.200000e-07  0.000034  0.000041  0.736847
# 179614  1.400000e-06  0.000150  0.000400  0.688646
# 193297  1.200000e-07  0.000033  0.000034 -0.009502
# 210625  7.800000e-08  0.001100  0.000640 -0.833271
# 214120  3.800000e-08  0.000490  0.000390  0.934538
# 231447  2.500000e-05  0.000300  0.000029  0.366116
#
# [39 rows x 22 columns]

# %%
# Number of family members included in ths slab
d_df_single = d_df_pred.drop_duplicates(subset = ["name_asteroid"])
num_family_slab = len(d_df_single[d_df_single["name_asteroid"].isin(name_list)])
print(f"Number of family members included in the slab: {num_family_slab}")
# Out:
# Number of family members included in the slab: 39

# %%
num_family_detected = d_df_pred[d_df_pred["d"] < 70].drop_duplicates(subset = ["name_asteroid"])
print(f"Number of detected family members within literature cutoff: {len(num_family_detected)}")
# Out:
# Number of detected family members within literature cutoff: 44

# %%
d_values = np.linspace(30, 140, 100)
percent_detected = []
cpu_hours = []
purity = []
d_published = 70
d_80_percent_cutoff = 63
d_80_precision_cutoff = 35.8

for d in d_values:
	filtered_df = d_df_pred[d_df_pred["d"] < d]
	filtered_df = filtered_df.drop_duplicates(subset = ["name_asteroid"])
	family_slab_df = filtered_df[filtered_df["name_asteroid"].isin(name_list)]
	cpu_hours.append(len(filtered_df) * 0.5)
	percent_detected.append(len(family_slab_df)/num_family_slab * 100)
	purity.append((len(family_slab_df)/(len(filtered_df))) * 100)

fig, (ax1, ax3) = plt.subplots(2, 1, sharex=True, figsize=(8, 8))

fig.text(-0.03, 0.5, 'Percent of family members detected', va='center', rotation='vertical', color=colors[4], fontsize=20)

ax1.plot(d_values, percent_detected, color=colors[4], rasterized=True)
# ax1.set_xlabel('d values')
# ax1.set_ylabel('Percent of family \n members detected', color=colors[4])
ax1.tick_params(axis='x')
ax1.tick_params(axis='y', labelcolor=colors[4])
ax1.axvline(x=d_published, color=colors[1], label = "literature cutoff", linestyle='--', linewidth=2)
ax1.axvline(x=d_80_percent_cutoff, color=colors[2], linestyle='-.', linewidth=2, label = "80% detected cutoff")
ax1.axvline(x=d_80_precision_cutoff, color=colors[3], linestyle=':', linewidth=3, label = "80% precision cutoff")
# ax1.set_title("Predicted")

ax2 = ax1.twinx()
ax2.plot(d_values, purity, color=colors[5], label='Purity', rasterized=True)
ax2.set_ylabel('Fraction of candidates in \n family (Precision)', color=colors[5])
ax2.tick_params(axis='y', labelcolor=colors[5])

ax3.plot(d_values, percent_detected, color=colors[4], rasterized=True)
ax3.set_xlabel('$d$ threshold')
# ax3.set_ylabel('Percent of family \n members detected', color=colors[4])
ax3.tick_params(axis='x')
ax3.tick_params(axis='y', labelcolor=colors[4])
ax3.axvline(x=d_published, color=colors[1], linestyle='--', linewidth=2, label = "literature cutoff")
ax3.axvline(x=d_80_percent_cutoff, color=colors[2], linestyle='-.', linewidth=2, label = "80% detected cutoff")
ax3.axvline(x=d_80_precision_cutoff, color=colors[3], linestyle=':', linewidth=3, label = "80% precision cutoff")
ax3.legend()

ax4 = ax3.twinx()
ax4.plot(d_values, cpu_hours, color=colors[6], label='CPU Hours')
ax4.set_ylabel('CPU Hours', color=colors[6])
ax4.tick_params(axis='y', labelcolor=colors[6])

fig.tight_layout()
plt.savefig("../plots/percent_precision_CPU.pdf", bbox_inches='tight')
plt.show()

# %%
print(f"Osculating CPU hours to reach 80%: {num_family_slab * 0.8 * 0.5}")
print(f"ML Proper CPU hours to reach 80%: {num_family_slab * 0.8 * 0.0094 * 1/3600}")
# Out:
# Osculating CPU hours to reach 80%: 15.600000000000001
# ML Proper CPU hours to reach 80%: 8.146666666666668e-05

# %%
d_values = np.linspace(10, 1000, 1000)

percent_detected_by_source = {
	"Osculating": [],
	"ML proper": []
}

for label, d_df in zip(["Osculating", "ML proper"], [d_df_osc, d_df_pred]):
	for d in d_values:
		filtered_df = d_df[d_df["d"] < d]
		filtered_df = filtered_df.drop_duplicates(subset=["name_asteroid"])
		family_slab_df = filtered_df[filtered_df["name_asteroid"].isin(name_list)]
		percent = len(family_slab_df) / num_family_slab * 100
		percent_detected_by_source[label].append(percent)

plt.figure(figsize=(10, 7))
plt.plot(d_values, percent_detected_by_source["Osculating"], label=f"Osculating", color=colors[3], rasterized=True)
plt.plot(d_values, percent_detected_by_source["ML proper"], label="ML proper", color=colors[0], rasterized=True)
plt.axvline(d_published, color=colors[1], linestyle="--", label="literature cutoff")
plt.axvline(d_80_percent_cutoff, color=colors[2], linestyle="-.", label="80% detected cutoff")
plt.axvline(d_80_precision_cutoff, color=colors[3], linestyle=":", label="80% precision cutoff")
plt.xlabel("d threshold")
plt.ylabel("Percent of family members detected")
# plt.title("Detection Rate vs. d Threshold")
plt.legend()
plt.tight_layout()
plt.savefig("../plots/detection_rate_d.pdf")
plt.show()

# %%
cpu_hours = {
	"Osculating": [],
	"ML proper": []
}
percent_detected = {
	"Osculating": [],
	"ML proper": []
}
for label, d_df in zip(["Osculating", "ML proper"], [d_df_osc, d_df_pred]):
	for d in d_values:
		filtered_df = d_df[d_df["d"] < d]
		filtered_df = filtered_df.drop_duplicates(subset=["name_asteroid"])
		family_slab_df = filtered_df[filtered_df["name_asteroid"].isin(name_list)]
		percent = len(family_slab_df) / num_family_slab * 100
		percent_detected[label].append(percent)
		cpu_hours[label].append(len(filtered_df) * 0.5)

plt.figure(figsize=(10, 7))
plt.plot(cpu_hours["Osculating"], percent_detected["Osculating"], label="Osculating", color=colors[3], rasterized=True)
plt.plot(cpu_hours["ML proper"], percent_detected["ML proper"], label="ML proper", color=colors[0], rasterized=True)
plt.xlabel("CPU Hours")
plt.ylabel("Percent of family members detected")
plt.title("Detection Rate vs. CPU Hours")
plt.legend()
plt.tight_layout()
plt.savefig("../plots/detection_CPU.pdf")
plt.show()

# %%
d = 70
filtered_df = d_df[d_df["d"] < d]
filtered_df = filtered_df.drop_duplicates(subset = ["name_asteroid"])
family_slab_df = filtered_df[filtered_df["name_asteroid"].isin(name_list)]
print(f"Percentage of family members detected: {len(family_slab_df)/num_family_slab * 100}")
print(f"Purity of the sample: {len(family_slab_df)/(len(filtered_df)) * 100}")
# Out:
# Percentage of family members detected: 84.61538461538461
# Purity of the sample: 75.0

# %% [markdown]
# # 2D plot generation

# %%
family_test_df = df_xgb[df_xgb["Des'n"].isin(name_list)]

# Define slab thresholds
threshold_e = 0.01
threshold_i = 0.01
threshold_a = 0.01

# Filter slab using proper elements
filter = (
    (propa < np.max(family_test_df["propa"]) + threshold_a) & (propa > np.min(family_test_df["propa"]) - threshold_a) &
    (prope < np.max(family_test_df["prope"]) + threshold_e) & (prope > np.min(family_test_df["prope"]) - threshold_e) &
    (propsini < np.max(family_test_df["propsini"]) + threshold_i) & (propsini > np.min(family_test_df["propsini"]) - threshold_i)
)

filtered = df_xgb[filter]
filtered = filtered[(filtered["Des'n"].isin(test_name_list)) & (~filtered["Des'n"].isin(name_list))]

fig, axes = plt.subplots(1, 3, figsize=(28, 7))

diff = max(family_test_df["prope"]) - min(filtered["prope"])

rect = patches.Rectangle(
    (min(filtered["prope"]), min(filtered["propsini"])),
    max(filtered["prope"]) - min(filtered["prope"]),
    max(filtered["propsini"]) - min(filtered["propsini"]),
    linewidth=1,
    edgecolor='r',
    facecolor='none'
)
axes[0].add_patch(rect)
axes[0].scatter(filtered["e"], (filtered["Incl."]*np.pi/180), s=4, alpha=1, label="Background asteroids", color='grey', rasterized=True)
axes[0].scatter(family_test_df["e"], (family_test_df["Incl."]*np.pi/180), s=20, label="Family members", color='red', rasterized=True)
axes[0].set_xlabel("Osculating e")
axes[0].set_ylabel("Osculating sin(i)")
# axes[0].set_xlim(min(filtered["e"]), min(filtered["e"]) + diff*4 + 0.01)
# axes[0].set_ylim(0.01, 0.09)
axes[0].set_aspect("equal")
axes[0].legend()
axes[0].set_title("Osculating e vs sin(i)")

rect = patches.Rectangle(
    (min(filtered["prope"]), min(filtered["propsini"])),
    max(filtered["prope"]) - min(filtered["prope"]),
    max(filtered["propsini"]) - min(filtered["propsini"]),
    linewidth=5,
    edgecolor='r',
    facecolor='none'
)
axes[1].scatter(filtered["pred_e"], filtered["pred_sini"], s=4, alpha=1, label="Slab asteroids", color='grey', rasterized=True)
axes[1].scatter(family_test_df["pred_e"], family_test_df["pred_sini"], s=20, label="Family members", color='red', rasterized=True)
axes[1].set_xlabel("ML Predicted e")
axes[1].set_ylabel("ML Predicted sin(i)")
axes[1].set_xlim(min(filtered["prope"]), max(filtered["prope"]))
axes[1].set_ylim(min(filtered["propsini"]), max(filtered["propsini"]))
axes[1].set_title("ML Predicted e vs sin(i)")
axes[1].add_patch(rect)
axes[1].set_aspect("equal")

rect = patches.Rectangle(
    (min(filtered["prope"]), min(filtered["propsini"])),
    max(filtered["prope"]) - min(filtered["prope"]),
    max(filtered["propsini"]) - min(filtered["propsini"]),
    linewidth=5,
    edgecolor='r',
    facecolor='none'
)
axes[2].scatter(filtered["prope"], filtered["propsini"], s=4, alpha=1, label="Slab asteroids", color='grey', rasterized=True)
axes[2].scatter(family_test_df["prope"], family_test_df["propsini"], s=20, label="Family members", color='red', rasterized=True)
axes[2].set_xlabel("Proper e")
axes[2].set_ylabel("Proper sin(i)")
axes[2].set_xlim(min(filtered["prope"]), max(filtered["prope"]))
axes[2].set_ylim(min(filtered["propsini"]), max(filtered["propsini"]))
axes[2].set_title("Proper e vs sin(i)")
axes[2].add_patch(rect)
axes[2].set_aspect("equal")

# plt.tight_layout(rect=[0.05, 0.05, 0.98, 0.95])
plt.savefig("../plots/2D_plots_family.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# # 3D plot generation

# %%
from matplotlib.ticker import FormatStrFormatter

formatter = FormatStrFormatter('%.3f')
family_test_df = family_df[family_df["Des'n"].isin(test_name_list)]
threshold_e = 0.01
threshold_i = 0.01
threshold_a = 0.01
filter = (propa < np.max(family_test_df["propa"]) + threshold_a) & (propa > np.min(family_test_df["propa"]) - threshold_a) &\
 (prope < np.max(family_test_df["prope"]) + threshold_e) & (prope > np.min(family_test_df["prope"])- threshold_e) &\
 (propsini < np.max(family_test_df["propsini"]) + threshold_i) & (propsini > np.min(family_test_df["propsini"])- threshold_i)
filtered = df_xgb[filter]
filtered = filtered[(filtered["Des'n"].isin(test_name_list)) & (~filtered["Des'n"].isin(name_list))]

fig = plt.figure(figsize=(18, 14))

threshold_e = 0.01
threshold_i = 0.01
threshold_a = 0.01
filter_osc = (propa < np.max(family_test_df["a"]) + threshold_a) & (propa > np.min(family_test_df["a"]) - threshold_a) &\
 (prope < np.max(family_test_df["e"]) + threshold_e) & (prope > np.min(family_test_df["e"])- threshold_e) &\
 (propsini < np.max(np.sin(family_test_df["Incl."] * np.pi/180)) + threshold_i) & (propsini > np.min(np.sin(family_test_df["Incl."] * np.pi/180)) - threshold_i)
filtered_osc = df_xgb[filter_osc]
filtered_osc = filtered_osc[(filtered_osc["Des'n"].isin(test_name_list)) & (~filtered_osc["Des'n"].isin(name_list))]

ax1 = fig.add_subplot(1, 3, 1, projection='3d')
ax1.scatter(filtered_osc["e"] / np.sqrt(2), np.sin(filtered_osc["Incl."]*np.pi/180) / np.sqrt(2), filtered_osc["a"] * 2.4 * np.sqrt(4/5), color="blue", s=1.5, alpha=0.05, label="Filtered")
ax1.scatter(family_test_df["e"] / np.sqrt(2), np.sin(family_test_df["Incl."] * np.pi/180) / np.sqrt(2), family_test_df["a"] * 2.4 * np.sqrt(4/5), color="red", s=2, label="Family")
ax1.set_xlabel("e", fontsize=14)
ax1.set_ylabel("sin(i)", fontsize=14)
ax1.set_zlabel("a", fontsize=14)
ax1.set_title("Osculating Orbital Elements", fontsize=20)
ax1.xaxis.set_major_formatter(formatter)
ax1.yaxis.set_major_formatter(formatter)
ax1.zaxis.set_major_formatter(formatter)
ax1.tick_params(axis='x', labelsize=12)
ax1.tick_params(axis='y', labelsize=12)
ax1.tick_params(axis='z', labelsize=12)
ax1.legend(fontsize=14)

ax2 = fig.add_subplot(1, 3, 2, projection='3d')
ax2.scatter(filtered["prope"] / np.sqrt(2), filtered["propsini"] / np.sqrt(2), filtered["propa"] * 2.4 * np.sqrt(4/5), color="blue", s=1.5, alpha=0.2, label="Filtered")
ax2.scatter(family_pred_df["pred_e"] / np.sqrt(2), family_pred_df["pred_sini"] / np.sqrt(2), family_pred_df["propa"] * 2.4 * np.sqrt(4/5), color="red", s=2, label="Family")
ax2.set_xlabel("ML Predicted Proper e", fontsize=14)
ax2.set_ylabel("ML Predicted Proper sin(i)", fontsize=14)
ax2.set_zlabel("Proper a", fontsize=14)
ax2.set_title("ML Predicted Proper Orbital Elements", fontsize=20)
ax2.xaxis.set_major_formatter(formatter)
ax2.yaxis.set_major_formatter(formatter)
ax2.zaxis.set_major_formatter(formatter)
ax2.tick_params(axis='x', labelsize=12)
ax2.tick_params(axis='y', labelsize=12)
ax2.tick_params(axis='z', labelsize=12)

ax3 = fig.add_subplot(1, 3, 3, projection='3d')
ax3.scatter(filtered["prope"] / np.sqrt(2), filtered["propsini"] / np.sqrt(2), filtered["propa"] * 2.4 * np.sqrt(4/5), color="blue", s=1.5, alpha=0.2, label="Filtered")
ax3.scatter(family_test_df["prope"] / np.sqrt(2), family_test_df["propsini"] / np.sqrt(2), family_test_df["propa"] * 2.4 * np.sqrt(4/5), color="red", s=2, label="Family")
ax3.set_xlabel("Proper e", fontsize=14)
ax3.set_ylabel("Proper sin(i)", fontsize=14)
ax3.set_zlabel("Proper a", fontsize=14)
ax3.set_title("Proper Orbital Elements", fontsize=20)
ax3.xaxis.set_major_formatter(formatter)
ax3.yaxis.set_major_formatter(formatter)
ax3.zaxis.set_major_formatter(formatter)
ax3.tick_params(axis='x', labelsize=12)
ax3.tick_params(axis='y', labelsize=12)
ax3.tick_params(axis='z', labelsize=12)

plt.savefig("../plots/3D_plot_family.pdf", bbox_inches = "tight")
